# %%
# %reset -f

arg1 = 10
arg2 = 'hehe'
arg3 = [0, 1, 5]

const2 = 'hehe-const'
const3 = [1, 5, 7]

def foo2(arg1):
    const1 = 'hm-cattto'
    foo(arg1)
    
def foo(arg1):
    print(arg1)
    print(foo2.const1)

    
foo2(arg1)
# Out:
# 10
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-44c20ff5862a> in <module>
#      17
#      18
# ---> 19 foo2(arg1)
#
# <ipython-input-1-44c20ff5862a> in foo2(arg1)
#      10 def foo2(arg1):
#      11     const1 = 'hm-cattto'
# ---> 12     foo(arg1)
#      13
#      14 def foo(arg1):
#
# <ipython-input-1-44c20ff5862a> in foo(arg1)
#      14 def foo(arg1):
#      15     print(arg1)
# ---> 16     print(foo2.const1)
#      17
#      18
#
# AttributeError: 'function' object has no attribute 'const1'

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-9fedacf9d37a> in <module>
#       5 plt.figure(1, figsize = (6, 4))
#       6 ax = plt.axes([0.1, 0.1, 0.8, 0.7])
# ----> 7 t = np.arange(0.0, 1.0+0.01, 0.01)
#       8 s = cos(2*2*pi*t)+2
#       9 plt.plot(t, s)
#
# NameError: name 'np' is not defined
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x0000000008A3BD90> (for post_execute):
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\pyplot.py in post_execute()
#     107             def post_execute():
#     108                 if matplotlib.is_interactive():
# --> 109                     draw_all()
#     110
#     111             # IPython >= 2
#
# ...
