# %% [markdown]
# ## Градиентная оптимизация

# %% [markdown]
# ### Производная

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
f = lambda x: x**4 + 5*x**3 - 10*x

# %%
x = np.linspace(-5, 2, 100)
fig, ax = plt.subplots()
ax.plot(x, f(x))
ax.set_ylabel('f(x)')
ax.set_xlabel('x')
plt.show()
